# %% [markdown]
# ## Images preprocess
# In this notebook will be created the corresponding dataframe with the all data needed for training purposes.
#
# This is assuming the datasets created before.

# %%
# Libraries
import pandas as pd
import json
import cv2
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# Functions
def get_routes_images(df_json):
    number_outfits = len(df_json)

    df_fashion = pd.DataFrame(columns=['Outfit','likes'])

    for i in range(number_outfits):
        df_fashion.loc[i, 'Outfit'] = df_json[i]['set_id']
        for j in range(len(df_json[i]['items'])):    
            df_fashion.loc[i, str(df_json[i]['items'][j]['categoryid'])] = df_json[i]['items'][j]['image']
        
        df_fashion.loc[i, 'likes'] = df_json[i]['likes']
        
    return df_fashion

# %% [markdown]
# ### Main Flow

# %%
# Loading the dataset
train_path = '../Datasets/womens_fashion_defined.json'
with open(train_path) as file:
  womens_fashion_datasetLimited = json.load(file)

train_path = '../Datasets/womens_fashion_wholeDataSet.json'
with open(train_path) as file:
  womens_fashion_wholeDataset = json.load(file)

# %% [markdown]
# **Dataframe with the outfit information**

# %%
outfits_df_limited = get_routes_images(womens_fashion_datasetLimited)
display(outfits_df_limited.head(5))
# Out:
#       Outfit likes                         19                         25  \
# 0  199683429    14  ../Images/199683429/1.jpg  ../Images/199683429/2.jpg
# 1  122754559     8                        NaN  ../Images/122754559/2.jpg
# 2  208049788   452                        NaN                        NaN
# 3  171294961    25                        NaN                        NaN
# 4  215569834    14                        NaN                        NaN
#
#                           28                        261  \
# 0  ../Images/199683429/3.jpg  ../Images/199683429/4.jpg
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN  ../Images/171294961/4.jpg
# 4                        NaN                        NaN
#
#                           21                        237  \
# 0                        NaN                        NaN
# 1  ../Images/122754559/1.jpg  ../Images/122754559/3.jpg
# 2  ../Images/208049788/1.jpg                        NaN
# 3                        NaN  ../Images/171294961/3.jpg
# 4                        NaN                        NaN
#
#                           49                         17  ...  264  236  257  \
# 0                        NaN                        NaN  ...  NaN  NaN  NaN
# 1  ../Images/122754559/4.jpg                        NaN  ...  NaN  NaN  NaN
# 2  ../Images/208049788/4.jpg  ../Images/208049788/2.jpg  ...  NaN  NaN  NaN
# 3                        NaN                        NaN  ...  NaN  NaN  NaN
# 4                        NaN                        NaN  ...  NaN  NaN  NaN
#
#    244 4517  255  256  309  239   15
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 46 columns]

# %%
outfits_df_whole = get_routes_images(womens_fashion_wholeDataset)
display(outfits_df_whole.head(5))
# Out:
#       Outfit likes                         21                        237  \
# 0  120161271     9  ../Images/120161271/1.jpg  ../Images/120161271/2.jpg
# 1  206969379     3                        NaN                        NaN
# 2  216220312   233                        NaN                        NaN
# 3  213824660   492                        NaN  ../Images/213824660/3.jpg
# 4  118117317  3979                        NaN                        NaN
#
#                           49                        106  \
# 0  ../Images/120161271/3.jpg  ../Images/120161271/8.jpg
# 1                        NaN                        NaN
# 2                        NaN  ../Images/216220312/5.jpg
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#                           11                        236  \
# 0                        NaN                        NaN
# 1  ../Images/206969379/1.jpg  ../Images/206969379/2.jpg
# 2                        NaN                        NaN
# 3  ../Images/213824660/1.jpg                        NaN
# 4                        NaN                        NaN
#
#                            9                        261  ...  320 4481  152  \
# 0                        NaN                        NaN  ...  NaN  NaN  NaN
# 1  ../Images/206969379/3.jpg  ../Images/206969379/4.jpg  ...  NaN  NaN  NaN
# 2                        NaN                        NaN  ...  NaN  NaN  NaN
# 3                        NaN  ../Images/213824660/4.jpg  ...  NaN  NaN  NaN
# 4                        NaN                        NaN  ...  NaN  NaN  NaN
#
#   4493  132  113  317  159 4488 4431
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 343 columns]

# %%
print("Number of outfits for all women:",len(outfits_df_whole))
print("Number of limited outfits",len(outfits_df_limited))
# Out:
# Number of outfits for all women: 7661
# Number of limited outfits 142

# %% [markdown]
# ### Processing the images with Cv2

# %%
def prepare_images(image_path):
    """
    Resize the all images at 64x64 and normalize the values of each image.
    """
    nparr = cv2.imread(image_path, cv2.IMREAD_COLOR)
    im = cv2.resize(nparr, (64,64))
    im = im/255
    return im

# %%
list_clothes = outfits_df_limited.columns[2:]
outfits_df = outfits_df_limited.replace('nan', np.NaN)
for clothing in list_clothes:
    for j in range(len(outfits_df[clothing])):
        if not pd.isna(outfits_df[clothing][j]):
                # print(outfits_df[clothing][j])
                prepare_images(outfits_df[clothing][j])

# %% [markdown]
# ### Are there enough data?
# I will eliminate the outfits that correspond to those columns that only have a single piece of data.

# %%
for _ in range(2):
    list_clothes = outfits_df.columns[2:]
    categorias_eliminar = []
    print(list_clothes)
    for clothing in list_clothes:
        # Fit the model created
        features = []
        for i in range(len(outfits_df[clothing])):
            if not pd.isna(outfits_df[clothing][i]):
                features.append(prepare_images(outfits_df[clothing][i]))
        
        # Convert the list of images into a single NumPy array
        x_train = np.array(features)
        if len(x_train) <= 3:
            categorias_eliminar.append(clothing)
            print(clothing)
            print("Size of the outfit:",len(x_train))

    for i in categorias_eliminar:
        outfits_df = outfits_df[outfits_df[i].isnull()]

    for i in categorias_eliminar:
        outfits_df = outfits_df.drop(i, axis=1)

    outfits_df = outfits_df.reset_index(drop=True)
outfits_df
# Out:
# Index(['19', '25', '28', '261', '21', '237', '49', '17', '27', '104', '18',
#        '4', '5', '2', '4495', '41', '29', '4496', '11', '23', '245', '52',
#        '24', '7', '3', '241', '9', '8', '26', '253', '240', '6', '263', '262',
#        '264', '236', '257', '244', '4517', '255', '256', '309', '239', '15'],
#       dtype='object')
# 23
# Size of the outfit: 2
# 245
# Size of the outfit: 2
# 52
# Size of the outfit: 2
# 3
# Size of the outfit: 2
# 253
# Size of the outfit: 2
# 6
# Size of the outfit: 1
# 262
# Size of the outfit: 2
# 264
# Size of the outfit: 1
# 257
# Size of the outfit: 2
# 244
# Size of the outfit: 1
# 4517
# Size of the outfit: 1
# 255
# Size of the outfit: 2
# 256
# Size of the outfit: 1
# 309
# Size of the outfit: 1
# 239
# Size of the outfit: 1
# 15
# Size of the outfit: 1
# Index(['19', '25', '28', '261', '21', '237', '49', '17', '27', '104', '18',
#        '4', '5', '2', '4495', '41', '29', '4496', '11', '24', '7', '241', '9',
#        '8', '26', '240', '263', '236'],
#       dtype='object')
# 5
# Size of the outfit: 3
#         Outfit likes                         19                         25  \
# 0    199683429    14  ../Images/199683429/1.jpg  ../Images/199683429/2.jpg
# 1    122754559     8                        NaN  ../Images/122754559/2.jpg
# 2    208049788   452                        NaN                        NaN
# 3    171294961    25                        NaN                        NaN
# 4    203338168    16                        NaN  ../Images/203338168/2.jpg
# ..         ...   ...                        ...                        ...
# 115  151982595     6                        NaN  ../Images/151982595/2.jpg
# 116  164701178    21                        NaN                        NaN
# 117  122342892    25                        NaN  ../Images/122342892/2.jpg
# 118  112415841   372                        NaN                        NaN
# 119  143829333  1372                        NaN  ../Images/143829333/3.jpg
#
#                             28                        261  \
# 0    ../Images/199683429/3.jpg  ../Images/199683429/4.jpg
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN  ../Images/171294961/4.jpg
# 4                          NaN                        NaN
# ..                         ...                        ...
# 115                        NaN  ../Images/151982595/7.jpg
# 116                        NaN                        NaN
# 117                        NaN                        NaN
# 118                        NaN                        NaN
# 119                        NaN                        NaN
#
#                             21                        237  \
# 0                          NaN                        NaN
# 1    ../Images/122754559/1.jpg  ../Images/122754559/3.jpg
# 2    ../Images/208049788/1.jpg                        NaN
# 3                          NaN  ../Images/171294961/3.jpg
# 4    ../Images/203338168/1.jpg  ../Images/203338168/3.jpg
# ..                         ...                        ...
# 115  ../Images/151982595/1.jpg                        NaN
# 116  ../Images/164701178/3.jpg  ../Images/164701178/7.jpg
# 117                        NaN                        NaN
# 118                        NaN                        NaN
# 119  ../Images/143829333/1.jpg  ../Images/143829333/4.jpg
#
#                             49                         17  ...  \
# 0                          NaN                        NaN  ...
# 1    ../Images/122754559/4.jpg                        NaN  ...
# 2    ../Images/208049788/4.jpg  ../Images/208049788/2.jpg  ...
# 3                          NaN                        NaN  ...
# 4    ../Images/203338168/4.jpg                        NaN  ...
# ..                         ...                        ...  ...
# 115                        NaN                        NaN  ...
# 116                        NaN                        NaN  ...
# 117  ../Images/122342892/4.jpg                        NaN  ...
# 118  ../Images/112415841/4.jpg                        NaN  ...
# 119  ../Images/143829333/5.jpg                        NaN  ...
#
#                             11                         24    7  \
# 0                          NaN                        NaN  NaN
# 1                          NaN                        NaN  NaN
# 2                          NaN                        NaN  NaN
# 3                          NaN                        NaN  NaN
# 4                          NaN                        NaN  NaN
# ..                         ...                        ...  ...
# 115                        NaN                        NaN  NaN
# 116  ../Images/164701178/5.jpg                        NaN  NaN
# 117  ../Images/122342892/1.jpg                        NaN  NaN
# 118  ../Images/112415841/1.jpg  ../Images/112415841/2.jpg  NaN
# 119                        NaN                        NaN  NaN
#
#                            241    9                          8   26  240  263  \
# 0                          NaN  NaN                        NaN  NaN  NaN  NaN
# 1                          NaN  NaN                        NaN  NaN  NaN  NaN
# 2                          NaN  NaN                        NaN  NaN  NaN  NaN
# 3                          NaN  NaN                        NaN  NaN  NaN  NaN
# 4                          NaN  NaN                        NaN  NaN  NaN  NaN
# ..                         ...  ...                        ...  ...  ...  ...
# 115  ../Images/151982595/5.jpg  NaN  ../Images/151982595/4.jpg  NaN  NaN  NaN
# 116  ../Images/164701178/8.jpg  NaN                        NaN  NaN  NaN  NaN
# 117                        NaN  NaN                        NaN  NaN  NaN  NaN
# 118                        NaN  NaN                        NaN  NaN  NaN  NaN
# 119                        NaN  NaN                        NaN  NaN  NaN  NaN
#
#                            236
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 115  ../Images/151982595/3.jpg
# 116                        NaN
# 117                        NaN
# 118                        NaN
# 119                        NaN
#
# [120 rows x 29 columns]

# %%
outfits_df.to_csv('../Datasets/outfits_training.csv', index=False)
